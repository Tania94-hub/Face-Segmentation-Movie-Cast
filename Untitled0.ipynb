# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir('/content/drive/MyDrive/')
# Out:
# ['Colab Notebooks',
#  'Image to pdf_24122022_165538 (1).pdf',
#  'Image to pdf_24122022_165538.pdf',
#  'Offer Letter_Tania Banerjee_1778466.pdf',
#  'Kuhelika (2).gdoc',
#  'Kuhelika (1).gdoc',
#  'Kuhelika.gdoc',
#  'NeilRatri (2).gdoc',
#  'NeilRatri (1).gdoc',
#  'NeilRatri.gdoc',
#  '.......gdoc',
#  'PF settlement process.pdf',
#  'No Dues Clearance Guidelines.pdf',
#  'Prospectus of policy portability.pdf',
#  'Educational Documents 1.pdf',
#  'Client Query Management System.gdoc',
#  'Bus_Ticket_TUD285363800 (1)',
#  'Bus_Ticket_TUD285363800',
#  'PYTHON MCQ.txt',
#  'Saved from Chrome',
#  'Tania_Banerjee_Resume (1).pdf',
#  'Tania_Banerjee_Resume.pdf']

# %%
os.listdir('/content/drive/MyDrive/Colab Notebooks/')
# Out:
# ['Untitled0.ipynb']

# %%
import os
os.listdir('/content/drive/MyDrive/')
# Out:
# ['Colab Notebooks',
#  'Image to pdf_24122022_165538 (1).pdf',
#  'Image to pdf_24122022_165538.pdf',
#  'Offer Letter_Tania Banerjee_1778466.pdf',
#  'Kuhelika (2).gdoc',
#  'Kuhelika (1).gdoc',
#  'Kuhelika.gdoc',
#  'NeilRatri (2).gdoc',
#  'NeilRatri (1).gdoc',
#  'NeilRatri.gdoc',
#  '.......gdoc',
#  'PF settlement process.pdf',
#  'No Dues Clearance Guidelines.pdf',
#  'Prospectus of policy portability.pdf',
#  'Educational Documents 1.pdf',
#  'Client Query Management System.gdoc',
#  'Bus_Ticket_TUD285363800 (1)',
#  'Bus_Ticket_TUD285363800',
#  'PYTHON MCQ.txt',
#  'Saved from Chrome',
#  'Tania_Banerjee_Resume (1).pdf',
#  'Tania_Banerjee_Resume.pdf']

# %%
import os
os.listdir('/content/drive/MyDrive/')
# Out:
# ['Colab Notebooks',
#  'Image to pdf_24122022_165538 (1).pdf',
#  'Image to pdf_24122022_165538.pdf',
#  'Offer Letter_Tania Banerjee_1778466.pdf',
#  'Kuhelika (2).gdoc',
#  'Kuhelika (1).gdoc',
#  'Kuhelika.gdoc',
#  'NeilRatri (2).gdoc',
#  'NeilRatri (1).gdoc',
#  'NeilRatri.gdoc',
#  '.......gdoc',
#  'PF settlement process.pdf',
#  'No Dues Clearance Guidelines.pdf',
#  'Prospectus of policy portability.pdf',
#  'Educational Documents 1.pdf',
#  'Client Query Management System.gdoc',
#  'Bus_Ticket_TUD285363800 (1)',
#  'Bus_Ticket_TUD285363800',
#  'PYTHON MCQ.txt',
#  'Saved from Chrome',
#  'Tania_Banerjee_Resume (1).pdf',
#  'Tania_Banerjee_Resume.pdf']

# %%
import os
os.listdir('/content/drive/MyDrive/')
# Out:
# ['Colab Notebooks',
#  'Image to pdf_24122022_165538 (1).pdf',
#  'Image to pdf_24122022_165538.pdf',
#  'Offer Letter_Tania Banerjee_1778466.pdf',
#  'Kuhelika (2).gdoc',
#  'Kuhelika (1).gdoc',
#  'Kuhelika.gdoc',
#  'NeilRatri (2).gdoc',
#  'NeilRatri (1).gdoc',
#  'NeilRatri.gdoc',
#  '.......gdoc',
#  'PF settlement process.pdf',
#  'No Dues Clearance Guidelines.pdf',
#  'Prospectus of policy portability.pdf',
#  'Educational Documents 1.pdf',
#  'Client Query Management System.gdoc',
#  'Bus_Ticket_TUD285363800 (1)',
#  'Bus_Ticket_TUD285363800',
#  'PYTHON MCQ.txt',
#  'Saved from Chrome',
#  'Tania_Banerjee_Resume (1).pdf',
#  'Tania_Banerjee_Resume.pdf']

# %%
import os
os.listdir('/content/drive/MyDrive/')
# Out:
# ['Colab Notebooks',
#  'Image to pdf_24122022_165538 (1).pdf',
#  'Image to pdf_24122022_165538.pdf',
#  'Offer Letter_Tania Banerjee_1778466.pdf',
#  'Kuhelika (2).gdoc',
#  'Kuhelika (1).gdoc',
#  'Kuhelika.gdoc',
#  'NeilRatri (2).gdoc',
#  'NeilRatri (1).gdoc',
#  'NeilRatri.gdoc',
#  '.......gdoc',
#  'PF settlement process.pdf',
#  'No Dues Clearance Guidelines.pdf',
#  'Prospectus of policy portability.pdf',
#  'Educational Documents 1.pdf',
#  'Client Query Management System.gdoc',
#  'Bus_Ticket_TUD285363800 (1)',
#  'Bus_Ticket_TUD285363800',
#  'PYTHON MCQ.txt',
#  'Saved from Chrome',
#  'Tania_Banerjee_Resume (1).pdf',
#  'Tania_Banerjee_Resume.pdf']

# %%
import os
os.listdir('/content/drive/MyDrive/')
# Out:
# ['Colab Notebooks',
#  'Image to pdf_24122022_165538 (1).pdf',
#  'Image to pdf_24122022_165538.pdf',
#  'Offer Letter_Tania Banerjee_1778466.pdf',
#  'Kuhelika (2).gdoc',
#  'Kuhelika (1).gdoc',
#  'Kuhelika.gdoc',
#  'NeilRatri (2).gdoc',
#  'NeilRatri (1).gdoc',
#  'NeilRatri.gdoc',
#  '.......gdoc',
#  'PF settlement process.pdf',
#  'No Dues Clearance Guidelines.pdf',
#  'Prospectus of policy portability.pdf',
#  'Educational Documents 1.pdf',
#  'Client Query Management System.gdoc',
#  'Bus_Ticket_TUD285363800 (1)',
#  'Bus_Ticket_TUD285363800',
#  'PYTHON MCQ.txt',
#  'Saved from Chrome',
#  'Tania_Banerjee_Resume (1).pdf',
#  'Tania_Banerjee_Resume.pdf']

# %%
import os

# Check if shared drives are accessible
print(os.listdir('/content/drive/'))
# Out:
# ['MyDrive', '.shortcut-targets-by-id', '.Trash-0', '.Encrypted']

# %%
os.listdir('/content/drive/.shortcut-targets-by-id/')
# Out:
# []

# %%
# !pip install gdown -q

# !gdown --folder "https://drive.google.com/drive/folders/1dBLCTJUU8DR8sHbjCESPafETLVWJ-z5S" --remaining-ok -O /content/data/

import os
print(os.listdir('/content/data/'))
# Out:
# Retrieving folder contents
# Retrieving folder 1Lj8RUAyMStUZRR9Mz_vEYsix7atYIfjA guvi april project
# Processing file 1gRZVgma-bJWxtiAwJ9eOYSGrjF6VwbKt Copy of Part 1- Train data - images.npy
# Processing file 1KnQj5hE4ZojEdkGDnD-MnI-3B-7EJH4D Copy of Part 1- Train data - images.npy
# Processing file 1mEfHHYOO59msn-lb92IqHR8ouURr3W5o Copy of Part 1- Train data - images.npy
# Processing file 1Vj7uiQqISDNfux64k24WrfvC9Jg5nV4s GUVI final project.pdf
# Processing file 1pFpwwHLzzrNWiTGFveOgNBMsCLxrG-Ni Part 1- Train data - images.npy
# Processing file 1veILDv1LWpvXqd1RIGfEIZlO27pXwA9x Part 1Test Data - Prediction Image.jpeg
# Processing file 1Yvt23MUSMhZSbuSzMbGRUP8MAXm10qAP Untitled0.ipynb
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1gRZVgma-bJWxtiAwJ9eOYSGrjF6VwbKt
# ...

# %%
import numpy as np

images = np.load('/content/data/GUVI Final Project/Part 1- Train data - images.npy')

print("Shape :", images.shape)
print("Dtype :", images.dtype)
print("Min   :", images.min())
print("Max   :", images.max())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9055/3435802300.py in <cell line: 0>()
#       1 import numpy as np
#       2
# ----> 3 images = np.load('/content/data/GUVI Final Project/Part 1- Train data - images.npy')
#       4
#       5 print("Shape :", images.shape)
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     482                                           max_header_size=max_header_size)
#     483             else:
# --> 484                 return format.read_array(fid, allow_pickle=allow_pickle,
#     485                                          pickle_kwargs=pickle_kwargs,
#     486                                          max_header_size=max_header_size)
#
# ...

# %%
import numpy as np

images = np.load('/content/data/GUVI Final Project/Part 1- Train data - images.npy', allow_pickle=True)

print("Shape :", images.shape)
print("Dtype :", images.dtype)
print("Min   :", images.min())
print("Max   :", images.max())
# Out:
# Shape : (409, 2)
# Dtype : object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9055/3227146473.py in <cell line: 0>()
#       5 print("Shape :", images.shape)
#       6 print("Dtype :", images.dtype)
# ----> 7 print("Min   :", images.min())
#       8 print("Max   :", images.max())
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      46 def _amin(a, axis=None, out=None, keepdims=False,
#      47           initial=_NoValue, where=True):
# ---> 48     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      49
#      50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# ValueError: operands could not be broadcast together with shapes (333,650,3) (2,)

# %%
import numpy as np

images = np.load('/content/data/GUVI Final Project/Part 1- Train data - images.npy', allow_pickle=True)

print("Total images  :", len(images))
print("Type of item  :", type(images[0]))
print("Shape image 0 :", images[0].shape)
print("Shape image 1 :", images[1].shape)
print("Shape image 2 :", images[2].shape)
print("Dtype image 0 :", images[0].dtype)
print("Min image 0   :", images[0].min())
print("Max image 0   :", images[0].max())
# Out:
# Total images  : 409
# Type of item  : <class 'numpy.ndarray'>
# Shape image 0 : (2,)
# Shape image 1 : (2,)
# Shape image 2 : (2,)
# Dtype image 0 : object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9055/1516822719.py in <cell line: 0>()
#       9 print("Shape image 2 :", images[2].shape)
#      10 print("Dtype image 0 :", images[0].dtype)
# ---> 11 print("Min image 0   :", images[0].min())
#      12 print("Max image 0   :", images[0].max())
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      46 def _amin(a, axis=None, out=None, keepdims=False,
#      47           initial=_NoValue, where=True):
# ---> 48     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      49
#      50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# ...

# %%
# Check exactly what's inside
print("images[0] type     :", type(images[0]))
print("images[0] dtype    :", images[0].dtype)
print("images[0] shape    :", images[0].shape)

# Look at the actual content
print("\nimages[0][0] type  :", type(images[0][0]))
print("images[0][0]       :", images[0][0])

# Maybe it's a tuple of (image, label) pairs?
print("\nFirst item full   :", images[0])
# Out:
# images[0] type     : <class 'numpy.ndarray'>
# images[0] dtype    : object
# images[0] shape    : (2,)
#
# images[0][0] type  : <class 'numpy.ndarray'>
# images[0][0]       : [[[42 37 34]
#   [56 51 48]
#   [71 66 63]
#   ...
#   [23 33 34]
#   [26 36 37]
#   [28 38 39]]
#
#  [[40 35 32]
#   [51 46 43]
#   [64 59 56]
#   ...
#   [27 36 35]
#   [24 33 32]
#   [26 35 34]]
#
#  [[43 38 35]
#   [51 46 43]
#   [61 56 53]
#   ...
#   [28 30 27]
#   [33 35 32]
#   [35 37 34]]
#
#  ...
#
#  [[56 47 40]
#   [57 48 41]
#   [61 52 45]
#   ...
#   [67 48 42]
#   [55 35 28]
#   [60 40 33]]
#
#  [[53 44 37]
#   [54 45 38]
#   [57 48 41]
#   ...
#   [59 40 34]
#   [60 40 33]
#   [54 34 27]]
#
#  [[53 44 37]
#   [54 45 38]
#   [57 48 41]
#   ...
#   [59 40 34]
#   [70 50 43]
#   [64 44 37]]]
#
# First item full   : [array([[[42, 37, 34],
#          [56, 51, 48],
#          [71, 66, 63],
#          ...,
#          [23, 33, 34],
#          [26, 36, 37],
#          [28, 38, 39]],
#
# ...

# %%
import matplotlib.pyplot as plt

# Try to visualize image 0 directly
try:
    plt.imshow(images[0])
    plt.title("Image 0")
    plt.show()
except Exception as e:
    print("Direct imshow failed:", e)

# Try accessing as nested
try:
    plt.imshow(images[0][0])
    plt.title("Image 0[0]")
    plt.show()
except Exception as e:
    print("images[0][0] failed:", e)
# Out:
# Direct imshow failed: Image data of dtype object cannot be converted to float

# %%
import numpy as np

# Check exactly what each element is
for i in range(3):
    item = images[i]
    print(f"\n--- Item {i} ---")
    print("type      :", type(item))
    print("shape     :", item.shape if hasattr(item, 'shape') else "no shape")
    print("dtype     :", item.dtype if hasattr(item, 'dtype') else "no dtype")
    print("len       :", len(item))

    # Check sub-elements
    sub = item[0]
    print("item[0] type  :", type(sub))
    print("item[0] shape :", sub.shape if hasattr(sub, 'shape') else sub)
# Out:
# --- Item 0 ---
# type      : <class 'numpy.ndarray'>
# shape     : (2,)
# dtype     : object
# len       : 2
# item[0] type  : <class 'numpy.ndarray'>
# item[0] shape : (333, 650, 3)
#
# --- Item 1 ---
# type      : <class 'numpy.ndarray'>
# shape     : (2,)
# dtype     : object
# len       : 2
# item[0] type  : <class 'numpy.ndarray'>
# item[0] shape : (697, 1280, 4)
#
# --- Item 2 ---
# type      : <class 'numpy.ndarray'>
# shape     : (2,)
# dtype     : object
# len       : 2
# item[0] type  : <class 'numpy.ndarray'>
# item[0] shape : (240, 460, 3)

# %%
# Print raw content of first item
print(images[0])
# Out:
# [array([[[42, 37, 34],
#          [56, 51, 48],
#          [71, 66, 63],
#          ...,
#          [23, 33, 34],
#          [26, 36, 37],
#          [28, 38, 39]],
#
#         [[40, 35, 32],
#          [51, 46, 43],
#          [64, 59, 56],
#          ...,
#          [27, 36, 35],
#          [24, 33, 32],
#          [26, 35, 34]],
#
#         [[43, 38, 35],
#          [51, 46, 43],
#          [61, 56, 53],
#          ...,
#          [28, 30, 27],
#          [33, 35, 32],
#          [35, 37, 34]],
#
#         ...,
#
#         [[56, 47, 40],
#          [57, 48, 41],
#          [61, 52, 45],
#          ...,
#          [67, 48, 42],
#          [55, 35, 28],
#          [60, 40, 33]],
#
#         [[53, 44, 37],
#          [54, 45, 38],
#          [57, 48, 41],
#          ...,
#          [59, 40, 34],
#          [60, 40, 33],
#          [54, 34, 27]],
#
#         [[53, 44, 37],
#          [54, 45, 38],
#          [57, 48, 41],
#          ...,
#          [59, 40, 34],
# ...

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

IMG_SIZE = 256

all_images = []
all_masks  = []

for idx, item in enumerate(images):
    img        = item[0]   # numpy image array
    annotations = item[1]  # list of face bounding boxes

    H, W = img.shape[:2]

    # Create blank mask
    mask = np.zeros((H, W), dtype=np.uint8)

    # Draw each face bounding box on the mask
    for ann in annotations:
        points = ann['points']
        x1 = int(points[0]['x'] * W)
        y1 = int(points[0]['y'] * H)
        x2 = int(points[1]['x'] * W)
        y2 = int(points[1]['y'] * H)

        # Fill face region white (255)
        mask[y1:y2, x1:x2] = 255

    # Resize both to 256x256
    img_resized  = cv2.resize(img,  (IMG_SIZE, IMG_SIZE))
    mask_resized = cv2.resize(mask, (IMG_SIZE, IMG_SIZE))

    all_images.append(img_resized)
    all_masks.append(mask_resized)

    if idx % 100 == 0:
        print(f"Processed {idx}/{len(images)}")

all_images = np.array(all_images, dtype=np.float32) / 255.0
all_masks  = np.array(all_masks,  dtype=np.float32) / 255.0

print(f"\nDone!")
print(f"Images shape : {all_images.shape}")
print(f"Masks shape  : {all_masks.shape}")
# Out:
# Processed 0/409
# Processed 100/409
# Processed 200/409
# Processed 300/409
# Processed 400/409
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9055/2428020300.py in <cell line: 0>()
#      38         print(f"Processed {idx}/{len(images)}")
#      39
# ---> 40 all_images = np.array(all_images, dtype=np.float32) / 255.0
#      41 all_masks  = np.array(all_masks,  dtype=np.float32) / 255.0
#      42
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 3 dimensions. The detected shape was (409, 256, 256) + inhomogeneous part.

# %%
import numpy as np
import cv2

IMG_SIZE = 256

all_images = []
all_masks  = []

for idx, item in enumerate(images):
    img        = item[0]
    annotations = item[1]

    H, W = img.shape[:2]

    # Fix: ensure image is always 3 channels (RGB)
    if len(img.shape) == 2:
        img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    elif img.shape[2] == 4:
        img = cv2.cvtColor(img, cv2.COLOR_RGBA2RGB)
    elif img.shape[2] == 3:
        pass  # already fine

    # Create blank mask
    mask = np.zeros((H, W), dtype=np.uint8)

    # Draw face bounding boxes
    for ann in annotations:
        points = ann['points']
        x1 = int(points[0]['x'] * W)
        y1 = int(points[0]['y'] * H)
        x2 = int(points[1]['x'] * W)
        y2 = int(points[1]['y'] * H)
        mask[y1:y2, x1:x2] = 255

    # Resize to 256x256
    img_resized  = cv2.resize(img,  (IMG_SIZE, IMG_SIZE))
    mask_resized = cv2.resize(mask, (IMG_SIZE, IMG_SIZE))

    all_images.append(img_resized)
    all_masks.append(mask_resized)

all_images = np.array(all_images, dtype=np.float32) / 255.0
all_masks  = np.array(all_masks,  dtype=np.float32) / 255.0

print(f"Images shape : {all_images.shape}")
print(f"Masks shape  : {all_masks.shape}")
# Out:
# Images shape : (409, 256, 256, 3)
# Masks shape  : (409, 256, 256)

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(4, 2, figsize=(10, 16))
for i in range(4):
    axes[i][0].imshow(all_images[i])
    axes[i][0].set_title(f"Image {i}")
    axes[i][0].axis('off')

    axes[i][1].imshow(all_masks[i], cmap='gray')
    axes[i][1].set_title(f"Mask {i} - Face Region")
    axes[i][1].axis('off')

plt.tight_layout()
plt.show()

# %%
import os
os.makedirs('/content/data/processed', exist_ok=True)

np.save('/content/data/processed/images.npy', all_images)
np.save('/content/data/processed/masks.npy',  all_masks)

print("Saved successfully!")
print(f"Images: {all_images.shape}")
print(f"Masks : {all_masks.shape}")
# Out:
# Saved successfully!
# Images: (409, 256, 256, 3)
# Masks : (409, 256, 256)

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    all_images, all_masks,
    test_size=0.2,
    random_state=42
)

# Add channel dim to masks
y_train = np.expand_dims(y_train, axis=-1)
y_val   = np.expand_dims(y_val,   axis=-1)

print(f"Train images : {X_train.shape}")
print(f"Train masks  : {y_train.shape}")
print(f"Val images   : {X_val.shape}")
print(f"Val masks    : {y_val.shape}")
# Out:
# Train images : (327, 256, 256, 3)
# Train masks  : (327, 256, 256, 1)
# Val images   : (82, 256, 256, 3)
# Val masks    : (82, 256, 256, 1)

# %%
import tensorflow as tf
import tensorflow.keras.backend as K

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    return dice_loss(y_true, y_pred) + bce

def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

print("Loss and metric functions defined!")
# Out:
# Loss and metric functions defined!

# %%
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import MobileNetV2

def build_unet(input_shape=(256, 256, 3)):
    base = MobileNetV2(input_shape=input_shape, include_top=False, weights='imagenet')
    base.trainable = False

    # Skip connections
    s1 = base.get_layer('block_1_expand_relu').output   # 128x128
    s2 = base.get_layer('block_3_expand_relu').output   # 64x64
    s3 = base.get_layer('block_6_expand_relu').output   # 32x32
    s4 = base.get_layer('block_13_expand_relu').output  # 16x16
    bridge = base.get_layer('block_16_project').output  # 8x8

    # Decoder
    def decoder_block(x, skip, filters):
        x = layers.Conv2DTranspose(filters, 3, strides=2, padding='same', activation='relu')(x)
        x = layers.Concatenate()([x, skip])
        x = layers.Conv2D(filters, 3, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
        return x

    x = decoder_block(bridge, s4, 256)
    x = decoder_block(x,      s3, 128)
    x = decoder_block(x,      s2, 64)
    x = decoder_block(x,      s1, 32)

    # Final upsample to 256x256
    x = layers.Conv2DTranspose(16, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv2D(1, 1, activation='sigmoid')(x)

    model = Model(inputs=base.input, outputs=x, name="UNet_MobileNetV2")
    return model

model = build_unet()
model.summary()
# Out:
# /tmp/ipykernel_9055/4216621216.py:5: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base = MobileNetV2(input_shape=input_shape, include_top=False, weights='imagenet')
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "UNet_MobileNetV2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 128, 128,  │        864 │ input_layer[0][0] │
# ...

# %%
import os
os.makedirs('/content/model', exist_ok=True)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=combined_loss,
    metrics=[dice_coefficient, iou_metric]
)

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        '/content/model/unet_best.h5',
        monitor='val_dice_coefficient',
        save_best_only=True,
        mode='max',
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_dice_coefficient',
        patience=10,
        mode='max',
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=8,
    callbacks=callbacks
)

print("Training complete!")
# Out:
# Epoch 1/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.2739 - iou_metric: 0.1624 - loss: 1.2527
# Epoch 1: val_dice_coefficient improved from None to 0.37226, saving model to /content/model/unet_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to /content/model/unet_best.h5
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 201s 5s/step - dice_coefficient: 0.3616 - iou_metric: 0.2262 - loss: 1.0650 - val_dice_coefficient: 0.3723 - val_iou_metric: 0.2325 - val_loss: 6.5905 - learning_rate: 0.0010
# Epoch 2/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coefficient: 0.5512 - iou_metric: 0.3829 - loss: 0.6936
# ...

# %%
import tensorflow as tf

def augment(image, mask):
    # Random flip
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask  = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask  = tf.image.flip_up_down(mask)
    # Random brightness/contrast
    image = tf.image.random_brightness(image, 0.15)
    image = tf.image.random_contrast(image, 0.8, 1.2)
    image = tf.clip_by_value(image, 0.0, 1.0)
    return image, mask

BATCH_SIZE = 8

train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_ds = train_ds.map(augment).shuffle(200).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))
val_ds = val_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

print("Augmented dataset ready!")
# Out:
# Augmented dataset ready!

# %%
import os

# Unfreeze all layers
for layer in model.layers:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss=combined_loss,
    metrics=[dice_coefficient, iou_metric]
)

callbacks_ft = [
    tf.keras.callbacks.ModelCheckpoint(
        '/content/model/unet_best.h5',
        monitor='val_dice_coefficient',
        save_best_only=True,
        mode='max',
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_dice_coefficient',
        patience=15,
        mode='max',
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=1
    )
]

history_ft = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=callbacks_ft
)

print("Fine-tuning complete!")
# Out:
# Epoch 1/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - dice_coefficient: 0.6284 - iou_metric: 0.4601 - loss: 0.6470
# Epoch 1: val_dice_coefficient improved from None to 0.70539, saving model to /content/model/unet_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to /content/model/unet_best.h5
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 305s 6s/step - dice_coefficient: 0.6374 - iou_metric: 0.4705 - loss: 0.6298 - val_dice_coefficient: 0.7054 - val_iou_metric: 0.5496 - val_loss: 0.5531 - learning_rate: 1.0000e-05
# Epoch 2/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - dice_coefficient: 0.6536 - iou_metric: 0.4870 - loss: 0.6020
# Epoch 2: val_dice_coefficient did not improve from 0.70539
# ...

# %%
from tensorflow.keras import layers, Model
import tensorflow as tf

def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(filters, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def build_custom_unet(input_shape=(256, 256, 3)):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = conv_block(inputs, 32)
    p1 = layers.MaxPooling2D()(c1)
    p1 = layers.Dropout(0.2)(p1)

    c2 = conv_block(p1, 64)
    p2 = layers.MaxPooling2D()(c2)
    p2 = layers.Dropout(0.2)(p2)

    c3 = conv_block(p2, 128)
    p3 = layers.MaxPooling2D()(c3)
    p3 = layers.Dropout(0.2)(p3)

    c4 = conv_block(p3, 256)
    p4 = layers.MaxPooling2D()(c4)
    p4 = layers.Dropout(0.3)(p4)

    # Bridge
    c5 = conv_block(p4, 512)

    # Decoder
    u6 = layers.Conv2DTranspose(256, 2, strides=2, padding='same')(c5)
    u6 = layers.Concatenate()([u6, c4])
    c6 = conv_block(u6, 256)
    c6 = layers.Dropout(0.3)(c6)

    u7 = layers.Conv2DTranspose(128, 2, strides=2, padding='same')(c6)
    u7 = layers.Concatenate()([u7, c3])
    c7 = conv_block(u7, 128)
    c7 = layers.Dropout(0.2)(c7)

    u8 = layers.Conv2DTranspose(64, 2, strides=2, padding='same')(c7)
    u8 = layers.Concatenate()([u8, c2])
    c8 = conv_block(u8, 64)
    c8 = layers.Dropout(0.2)(c8)

    u9 = layers.Conv2DTranspose(32, 2, strides=2, padding='same')(c8)
    u9 = layers.Concatenate()([u9, c1])
    c9 = conv_block(u9, 32)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(c9)

    model = Model(inputs, outputs, name='Custom_UNet')
    return model

model2 = build_custom_unet()
model2.summary()
# Out:
# Model: "Custom_UNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 256, 256,  │        896 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
import numpy as np

np.save('/content/drive/MyDrive/images_processed.npy', all_images)
np.save('/content/drive/MyDrive/masks_processed.npy',  all_masks)
print("Data saved to Drive safely!")
# Out:
# Data saved to Drive safely!

# %%
import os
os.makedirs('/content/model', exist_ok=True)

model2.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=combined_loss,
    metrics=[dice_coefficient, iou_metric]
)

callbacks2 = [
    tf.keras.callbacks.ModelCheckpoint(
        '/content/model/custom_unet_best.h5',
        monitor='val_dice_coefficient',
        save_best_only=True,
        mode='max',
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_dice_coefficient',
        patience=15,
        mode='max',
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.3,
        patience=5,
        min_lr=1e-7,
        verbose=1
    )
]

history2 = model2.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=callbacks2
)

print("Training complete!")
# Out:
# Epoch 1/100
#  7/41 ━━━━━━━━━━━━━━━━━━━━ 11:02 19s/step - dice_coefficient: 0.2188 - iou_metric: 0.1240 - loss: 1.2675
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9055/4059130125.py in <cell line: 0>()
#      32 ]
#      33
# ---> 34 history2 = model2.fit(
#      35     train_ds,
#      36     validation_data=val_ds,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
np.save('/content/drive/MyDrive/images_processed.npy', all_images)
np.save('/content/drive/MyDrive/masks_processed.npy',  all_masks)
print("Saved!")
# Out:
# Saved!

# %%
# Cell 1 - Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cell 2 - Reload processed data
import numpy as np
all_images = np.load('/content/drive/MyDrive/images_processed.npy')
all_masks  = np.load('/content/drive/MyDrive/masks_processed.npy')
print("Images:", all_images.shape)
print("Masks :", all_masks.shape)
# Out:
# Images: (409, 256, 256, 3)
# Masks : (409, 256, 256)

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    all_images, all_masks, test_size=0.2, random_state=42)

y_train = np.expand_dims(y_train, axis=-1)
y_val   = np.expand_dims(y_val,   axis=-1)

print("X_train:", X_train.shape)
print("X_val  :", X_val.shape)
# Out:
# X_train: (327, 256, 256, 3)
# X_val  : (82, 256, 256, 3)

# %%
import tensorflow as tf
import tensorflow.keras.backend as K

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    return dice_loss(y_true, y_pred) + bce

def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

print("Loss functions ready!")
# Out:
# Loss functions ready!

# %%
import tensorflow as tf

def augment(image, mask):
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask  = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask  = tf.image.flip_up_down(mask)
    image = tf.image.random_brightness(image, 0.15)
    image = tf.image.random_contrast(image, 0.8, 1.2)
    image = tf.clip_by_value(image, 0.0, 1.0)
    return image, mask

BATCH_SIZE = 8

train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_ds = train_ds.map(augment).shuffle(200).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))
val_ds = val_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

print("Augmentation ready!")
# Out:
# Augmentation ready!

# %%
from tensorflow.keras import layers, Model

def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(filters, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def build_custom_unet(input_shape=(256, 256, 3)):
    inputs = layers.Input(input_shape)

    c1 = conv_block(inputs, 32)
    p1 = layers.MaxPooling2D()(c1)
    p1 = layers.Dropout(0.2)(p1)

    c2 = conv_block(p1, 64)
    p2 = layers.MaxPooling2D()(c2)
    p2 = layers.Dropout(0.2)(p2)

    c3 = conv_block(p2, 128)
    p3 = layers.MaxPooling2D()(c3)
    p3 = layers.Dropout(0.2)(p3)

    c4 = conv_block(p3, 256)
    p4 = layers.MaxPooling2D()(c4)
    p4 = layers.Dropout(0.3)(p4)

    c5 = conv_block(p4, 512)

    u6 = layers.Conv2DTranspose(256, 2, strides=2, padding='same')(c5)
    u6 = layers.Concatenate()([u6, c4])
    c6 = conv_block(u6, 256)
    c6 = layers.Dropout(0.3)(c6)

    u7 = layers.Conv2DTranspose(128, 2, strides=2, padding='same')(c6)
    u7 = layers.Concatenate()([u7, c3])
    c7 = conv_block(u7, 128)
    c7 = layers.Dropout(0.2)(c7)

    u8 = layers.Conv2DTranspose(64, 2, strides=2, padding='same')(c7)
    u8 = layers.Concatenate()([u8, c2])
    c8 = conv_block(u8, 64)
    c8 = layers.Dropout(0.2)(c8)

    u9 = layers.Conv2DTranspose(32, 2, strides=2, padding='same')(c8)
    u9 = layers.Concatenate()([u9, c1])
    c9 = conv_block(u9, 32)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(c9)
    return Model(inputs, outputs, name='Custom_UNet')

model2 = build_custom_unet()
print("Model built!")
# Out:
# Model built!

# %%
import os
os.makedirs('/content/model', exist_ok=True)

model2.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=combined_loss,
    metrics=[dice_coefficient, iou_metric]
)

callbacks2 = [
    tf.keras.callbacks.ModelCheckpoint(
        '/content/model/custom_unet_best.h5',
        monitor='val_dice_coefficient',
        save_best_only=True,
        mode='max', verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_dice_coefficient',
        patience=15, mode='max',
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.3,
        patience=5, min_lr=1e-7, verbose=1
    )
]

history2 = model2.fit(
    train_ds, validation_data=val_ds,
    epochs=100, callbacks=callbacks2
)

print("Training complete!")
# Out:
# Epoch 1/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coefficient: 0.2696 - iou_metric: 0.1571 - loss: 1.1845
# Epoch 1: val_dice_coefficient improved from None to 0.16261, saving model to /content/model/custom_unet_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to /content/model/custom_unet_best.h5
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 102s 1s/step - dice_coefficient: 0.2861 - iou_metric: 0.1683 - loss: 1.1249 - val_dice_coefficient: 0.1626 - val_iou_metric: 0.0887 - val_loss: 1.6399 - learning_rate: 0.0010
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - dice_coefficient: 0.3277 - iou_metric: 0.1970 - loss: 1.0423
# ...

# %%
# !pip install albumentations -q

# %%
import albumentations as A
import numpy as np
import cv2

# Strong augmentation pipeline
aug = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.3),

    A.Rotate(
        limit=30,
        border_mode=cv2.BORDER_REFLECT_101,
        p=0.5
    ),

    A.RandomBrightnessContrast(p=0.4),

    A.GaussianBlur(
        blur_limit=(3, 5),
        p=0.3
    ),

    A.ElasticTransform(
        alpha=1,
        sigma=50,
        p=0.3
    ),

    A.RandomResizedCrop(
        size=(256, 256),
        scale=(0.8, 1.0),
        p=0.4
    ),
])

# Lists for augmented data
aug_images = []
aug_masks = []

# Generate augmented dataset
for _ in range(3):   # triple the dataset

    for img, mask in zip(X_train, y_train[:, :, :, 0]):

        # Convert to uint8
        img_uint8 = (img * 255).astype(np.uint8)
        mask_uint8 = (mask * 255).astype(np.uint8)

        # Apply augmentation
        result = aug(
            image=img_uint8,
            mask=mask_uint8
        )

        # Normalize back
        aug_img = result['image'].astype(np.float32) / 255.0
        aug_mask = result['mask'].astype(np.float32) / 255.0

        aug_images.append(aug_img)
        aug_masks.append(aug_mask)

# Convert to numpy arrays
aug_images = np.array(aug_images, dtype=np.float32)

aug_masks = np.expand_dims(
    np.array(aug_masks, dtype=np.float32),
    axis=-1
)

# Convert masks back to binary
aug_masks = (aug_masks > 0.5).astype(np.float32)

# Combine original + augmented data
X_train_aug = np.concatenate(
    [X_train, aug_images],
    axis=0
)

y_train_aug = np.concatenate(
    [y_train, aug_masks],
    axis=0
)

# Print final shapes
print("Original X_train shape :", X_train.shape)
print("Augmented images shape :", aug_images.shape)
print("Final X_train_aug shape:", X_train_aug.shape)

print("Original y_train shape :", y_train.shape)
print("Augmented masks shape  :", aug_masks.shape)
print("Final y_train_aug shape:", y_train_aug.shape)
# Out:
# Original X_train shape : (327, 256, 256, 3)
# Augmented images shape : (981, 256, 256, 3)
# Final X_train_aug shape: (1308, 256, 256, 3)
# Original y_train shape : (327, 256, 256, 1)
# Augmented masks shape  : (981, 256, 256, 1)
# Final y_train_aug shape: (1308, 256, 256, 1)

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, Model

def build_vgg16_unet(input_shape=(256, 256, 3)):
    base = VGG16(input_shape=input_shape, include_top=False, weights='imagenet')
    base.trainable = False

    s1 = base.get_layer('block1_conv2').output  # 256x256
    s2 = base.get_layer('block2_conv2').output  # 128x128
    s3 = base.get_layer('block3_conv2').output  # 64x64
    s4 = base.get_layer('block4_conv2').output  # 32x32
    bridge = base.get_layer('block5_conv2').output  # 16x16

    def dec_block(x, skip, filters):
        x = layers.Conv2DTranspose(filters, 2, strides=2, padding='same')(x)
        x = layers.Concatenate()([x, skip])
        x = layers.Conv2D(filters, 3, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Conv2D(filters, 3, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
        return x

    x = dec_block(bridge, s4, 256)
    x = dec_block(x,      s3, 128)
    x = dec_block(x,      s2, 64)
    x = dec_block(x,      s1, 32)

    x = layers.Conv2DTranspose(16, 2, strides=2, padding='same', activation='relu')(x)
    output = layers.Conv2D(1, 1, activation='sigmoid')(x)

    return Model(inputs=base.input, outputs=output, name='VGG16_UNet')

model3 = build_vgg16_unet()
print("VGG16 U-Net ready!")
# Out:
# ...
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# VGG16 U-Net ready!

# %%
import tensorflow as tf

train_ds3 = tf.data.Dataset.from_tensor_slices((X_train_aug, y_train_aug))
train_ds3 = train_ds3.shuffle(500).batch(8).prefetch(tf.data.AUTOTUNE)

val_ds3 = tf.data.Dataset.from_tensor_slices((X_val, y_val))
val_ds3  = val_ds3.batch(8).prefetch(tf.data.AUTOTUNE)

model3.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=combined_loss,
    metrics=[dice_coefficient, iou_metric]
)

callbacks3 = [
    tf.keras.callbacks.ModelCheckpoint(
        '/content/model/vgg16_unet_best.h5',
        monitor='val_dice_coefficient',
        save_best_only=True, mode='max', verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_dice_coefficient',
        patience=15, mode='max',
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.3,
        patience=5, min_lr=1e-7, verbose=1
    )
]

history3 = model3.fit(
    train_ds3, validation_data=val_ds3,
    epochs=80, callbacks=callbacks3
)
print("VGG16 training complete!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15423/1065985624.py in <cell line: 0>()
#       1 import tensorflow as tf
#       2
# ----> 3 train_ds3 = tf.data.Dataset.from_tensor_slices((X_train_aug, y_train_aug))
#       4 train_ds3 = train_ds3.shuffle(500).batch(8).prefetch(tf.data.AUTOTUNE)
#       5
#
# NameError: name 'X_train_aug' is not defined

# %%
import albumentations as A
import numpy as np

# Strong augmentation pipeline
aug = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.3),
    A.Rotate(limit=30, p=0.5),
    A.RandomBrightnessContrast(p=0.4),
    A.GaussianBlur(p=0.3),
    A.ElasticTransform(p=0.3),
])

# Triple the training data
aug_images, aug_masks = [], []

for _ in range(3):
    for img, mask in zip(X_train, y_train[:, :, :, 0]):
        img_uint8  = (img * 255).astype(np.uint8)
        mask_uint8 = (mask * 255).astype(np.uint8)
        result = aug(image=img_uint8, mask=mask_uint8)
        aug_images.append(result['image'] / 255.0)
        aug_masks.append(result['mask']  / 255.0)

aug_images = np.array(aug_images, dtype=np.float32)
aug_masks  = np.expand_dims(np.array(aug_masks, dtype=np.float32), axis=-1)

X_train_aug = np.concatenate([X_train, aug_images], axis=0)
y_train_aug = np.concatenate([y_train, aug_masks],  axis=0)

print(f"Original train size : {X_train.shape[0]}")
print(f"Augmented train size: {X_train_aug.shape[0]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15423/4157489042.py in <cell line: 0>()
#      16
#      17 for _ in range(3):
# ---> 18     for img, mask in zip(X_train, y_train[:, :, :, 0]):
#      19         img_uint8  = (img * 255).astype(np.uint8)
#      20         mask_uint8 = (mask * 255).astype(np.uint8)
#
# NameError: name 'X_train' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
all_images = np.load('/content/drive/MyDrive/images_processed.npy')
all_masks  = np.load('/content/drive/MyDrive/masks_processed.npy')
print("Images:", all_images.shape)
print("Masks :", all_masks.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Images: (409, 256, 256, 3)
# Masks : (409, 256, 256)

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    all_images, all_masks, test_size=0.2, random_state=42)

y_train = np.expand_dims(y_train, axis=-1)
y_val   = np.expand_dims(y_val,   axis=-1)

print("X_train:", X_train.shape)
print("X_val  :", X_val.shape)
# Out:
# X_train: (327, 256, 256, 3)
# X_val  : (82, 256, 256, 3)

# %%
import tensorflow as tf
import tensorflow.keras.backend as K

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    return dice_loss(y_true, y_pred) + bce

def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

print("Loss functions ready!")
# Out:
# Loss functions ready!

# %%
# !pip install albumentations -q
import albumentations as A

aug = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.3),
    A.Rotate(limit=30, p=0.5),
    A.RandomBrightnessContrast(p=0.4),
    A.GaussianBlur(p=0.3),
    A.ElasticTransform(p=0.3),
])

aug_images, aug_masks = [], []

for _ in range(3):
    for img, mask in zip(X_train, y_train[:, :, :, 0]):
        img_uint8  = (img * 255).astype(np.uint8)
        mask_uint8 = (mask * 255).astype(np.uint8)
        result = aug(image=img_uint8, mask=mask_uint8)
        aug_images.append(result['image'] / 255.0)
        aug_masks.append(result['mask']  / 255.0)

aug_images  = np.array(aug_images, dtype=np.float32)
aug_masks   = np.expand_dims(np.array(aug_masks, dtype=np.float32), axis=-1)

X_train_aug = np.concatenate([X_train, aug_images], axis=0)
y_train_aug = np.concatenate([y_train, aug_masks],  axis=0)

print(f"Augmented train size: {X_train_aug.shape[0]}")
# Out:
# Augmented train size: 1308

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, Model

def build_vgg16_unet(input_shape=(256, 256, 3)):
    base = VGG16(input_shape=input_shape, include_top=False, weights='imagenet')
    base.trainable = False

    s1     = base.get_layer('block1_conv2').output
    s2     = base.get_layer('block2_conv2').output
    s3     = base.get_layer('block3_conv2').output
    s4     = base.get_layer('block4_conv2').output
    bridge = base.get_layer('block5_conv2').output

    def dec_block(x, skip, filters):
        x = layers.Conv2DTranspose(filters, 2, strides=2, padding='same')(x)
        x = layers.Concatenate()([x, skip])
        x = layers.Conv2D(filters, 3, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Conv2D(filters, 3, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
        return x

    x = dec_block(bridge, s4, 256)
    x = dec_block(x,      s3, 128)
    x = dec_block(x,      s2, 64)
    x = dec_block(x,      s1, 32)
    x = layers.Conv2DTranspose(16, 2, strides=2, padding='same', activation='relu')(x)
    output = layers.Conv2D(1, 1, activation='sigmoid')(x)

    return Model(inputs=base.input, outputs=output, name='VGG16_UNet')

model3 = build_vgg16_unet()
print("VGG16 U-Net ready!")
# Out:
# VGG16 U-Net ready!

# %%
import os, tensorflow as tf
os.makedirs('/content/model', exist_ok=True)

train_ds3 = tf.data.Dataset.from_tensor_slices((X_train_aug, y_train_aug))
train_ds3 = train_ds3.shuffle(500).batch(8).prefetch(tf.data.AUTOTUNE)

val_ds3 = tf.data.Dataset.from_tensor_slices((X_val, y_val))
val_ds3 = val_ds3.batch(8).prefetch(tf.data.AUTOTUNE)

model3.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=combined_loss,
    metrics=[dice_coefficient, iou_metric]
)

callbacks3 = [
    tf.keras.callbacks.ModelCheckpoint(
        '/content/model/vgg16_unet_best.h5',
        monitor='val_dice_coefficient',
        save_best_only=True, mode='max', verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_dice_coefficient',
        patience=15, mode='max',
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.3,
        patience=5, min_lr=1e-7, verbose=1
    )
]

history3 = model3.fit(
    train_ds3, validation_data=val_ds3,
    epochs=80, callbacks=callbacks3
)
print("Training complete!")
# Out:
# Epoch 1/80
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_15423/887305658.py in <cell line: 0>()
#      31 ]
#      32
# ---> 33 history3 = model3.fit(
#      34     train_ds3, validation_data=val_ds3,
#      35     epochs=80, callbacks=callbacks3
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /tmp/ipykernel_15423/1947669600.py in combined_loss(y_true, y_pred)
#      12
#      13 def combined_loss(y_true, y_pred):
# ---> 14     bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
# ...

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, Model

def build_vgg16_unet(input_shape=(256, 256, 3)):
    base = VGG16(input_shape=input_shape, include_top=False, weights='imagenet')
    base.trainable = False

    s1     = base.get_layer('block1_conv2').output  # 256x256
    s2     = base.get_layer('block2_conv2').output  # 128x128
    s3     = base.get_layer('block3_conv2').output  # 64x64
    s4     = base.get_layer('block4_conv2').output  # 32x32
    bridge = base.get_layer('block5_conv2').output  # 16x16

    def dec_block(x, skip, filters):
        x = layers.Conv2DTranspose(filters, 2, strides=2, padding='same')(x)
        x = layers.Concatenate()([x, skip])
        x = layers.Conv2D(filters, 3, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Conv2D(filters, 3, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
        return x

    x = dec_block(bridge, s4, 256)  # 16→32
    x = dec_block(x,      s3, 128)  # 32→64
    x = dec_block(x,      s2, 64)   # 64→128
    x = dec_block(x,      s1, 32)   # 128→256

    # Output directly at 256x256 — no extra upsample
    output = layers.Conv2D(1, 1, activation='sigmoid')(x)

    return Model(inputs=base.input, outputs=output, name='VGG16_UNet')

model3 = build_vgg16_unet()
print("VGG16 U-Net ready! Output shape:", model3.output_shape)
# Out:
# VGG16 U-Net ready! Output shape: (None, 256, 256, 1)

# %%
import os, tensorflow as tf
os.makedirs('/content/model', exist_ok=True)

train_ds3 = tf.data.Dataset.from_tensor_slices((X_train_aug, y_train_aug))
train_ds3 = train_ds3.shuffle(500).batch(8).prefetch(tf.data.AUTOTUNE)

val_ds3 = tf.data.Dataset.from_tensor_slices((X_val, y_val))
val_ds3 = val_ds3.batch(8).prefetch(tf.data.AUTOTUNE)

model3.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=combined_loss,
    metrics=[dice_coefficient, iou_metric]
)

callbacks3 = [
    tf.keras.callbacks.ModelCheckpoint(
        '/content/model/vgg16_unet_best.h5',
        monitor='val_dice_coefficient',
        save_best_only=True, mode='max', verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_dice_coefficient',
        patience=15, mode='max',
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.3,
        patience=5, min_lr=1e-7, verbose=1
    )
]

history3 = model3.fit(
    train_ds3, validation_data=val_ds3,
    epochs=80, callbacks=callbacks3
)
print("Training complete!")
# Out:
# Epoch 1/80
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - dice_coefficient: 0.3625 - iou_metric: 0.2251 - loss: 1.1626
# Epoch 1: val_dice_coefficient improved from None to 0.63227, saving model to /content/model/vgg16_unet_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to /content/model/vgg16_unet_best.h5
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 109s 430ms/step - dice_coefficient: 0.4227 - iou_metric: 0.2724 - loss: 0.9905 - val_dice_coefficient: 0.6323 - val_iou_metric: 0.4658 - val_loss: 1.2984 - learning_rate: 0.0010
# Epoch 2/80
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - dice_coefficient: 0.5682 - iou_metric: 0.4004 - loss: 0.6839
# ...

# %%
# Unfreeze top layers of VGG16
for layer in model3.get_layer('vgg16').layers[-6:]:
    layer.trainable = True

model3.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss=combined_loss,
    metrics=[dice_coefficient, iou_metric]
)

callbacks_ft = [
    tf.keras.callbacks.ModelCheckpoint(
        '/content/model/vgg16_unet_best.h5',
        monitor='val_dice_coefficient',
        save_best_only=True, mode='max', verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_dice_coefficient',
        patience=10, mode='max',
        restore_best_weights=True, verbose=1
    )
]

history_ft = model3.fit(
    train_ds3, validation_data=val_ds3,
    epochs=30, callbacks=callbacks_ft
)
print("Fine-tuning done!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_15423/1748856166.py in <cell line: 0>()
#       1 # Unfreeze top layers of VGG16
# ----> 2 for layer in model3.get_layer('vgg16').layers[-6:]:
#       3     layer.trainable = True
#       4
#       5 model3.compile(
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/models/model.py in get_layer(self, name, index)
#     211                 if layer.name == name:
#     212                     return layer
# --> 213             raise ValueError(
# ...

# %%
# Unfreeze last VGG16 layers directly
layers_to_unfreeze = ['block5_conv1', 'block5_conv2',
                      'block4_conv1', 'block4_conv2', 'block4_conv3']

for layer in model3.layers:
    if layer.name in layers_to_unfreeze:
        layer.trainable = True
        print(f"Unfrozen: {layer.name}")

model3.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss=combined_loss,
    metrics=[dice_coefficient, iou_metric]
)

callbacks_ft = [
    tf.keras.callbacks.ModelCheckpoint(
        '/content/model/vgg16_unet_best.h5',
        monitor='val_dice_coefficient',
        save_best_only=True, mode='max', verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_dice_coefficient',
        patience=10, mode='max',
        restore_best_weights=True, verbose=1
    )
]

history_ft = model3.fit(
    train_ds3, validation_data=val_ds3,
    epochs=30, callbacks=callbacks_ft
)
print("Fine-tuning done!")
# Out:
# Unfrozen: block4_conv1
# Unfrozen: block4_conv2
# Unfrozen: block4_conv3
# Unfrozen: block5_conv1
# Unfrozen: block5_conv2
# Epoch 1/30
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - dice_coefficient: 0.8781 - iou_metric: 0.7842 - loss: 0.1936
# Epoch 1: val_dice_coefficient improved from None to 0.63381, saving model to /content/model/vgg16_unet_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to /content/model/vgg16_unet_best.h5
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - dice_coefficient: 0.8795 - iou_metric: 0.7864 - loss: 0.1890 - val_dice_coefficient: 0.6338 - val_iou_metric: 0.4684 - val_loss: 0.7077
# Epoch 2/30
# ...

# %%
import time
import numpy as np
from sklearn.metrics import f1_score

dice_scores, iou_scores, f1_scores, times = [], [], [], []

for i in range(len(X_val)):
    img_batch = np.expand_dims(X_val[i], 0)
    true_mask = y_val[i, :, :, 0].flatten().astype(np.uint8)

    start = time.time()
    pred  = model3.predict(img_batch, verbose=0)[0, :, :, 0]
    elapsed = (time.time() - start) * 1000

    pred_binary = (pred > 0.5).astype(np.uint8).flatten()

    intersection = np.sum(true_mask * pred_binary)
    dice = (2 * intersection + 1e-6) / (np.sum(true_mask) + np.sum(pred_binary) + 1e-6)
    iou  = (intersection + 1e-6) / (np.sum(true_mask) + np.sum(pred_binary) - intersection + 1e-6)
    f1   = f1_score(true_mask, pred_binary, zero_division=0)

    dice_scores.append(dice)
    iou_scores.append(iou)
    f1_scores.append(f1)
    times.append(elapsed)

import pandas as pd
summary = pd.DataFrame({
    'Metric':  ['Dice Coefficient', 'IoU', 'F1 Score', 'Avg Inference Speed'],
    'Score':   [f"{np.mean(dice_scores):.4f}", f"{np.mean(iou_scores):.4f}",
                f"{np.mean(f1_scores):.4f}",  f"{np.mean(times):.1f} ms"],
    'Target':  ['>0.92', '>0.88', '>0.90', '<100ms']
})
print(summary)
# Out:
#                 Metric     Score  Target
# 0     Dice Coefficient    0.6173   >0.92
# 1                  IoU    0.4701   >0.88
# 2             F1 Score    0.6173   >0.90
# 3  Avg Inference Speed  237.3 ms  <100ms

# %%
import shutil, matplotlib.pyplot as plt

# Save model
shutil.copy('/content/model/vgg16_unet_best.h5',
            '/content/drive/MyDrive/vgg16_unet_best.h5')

# Save sample predictions
fig, axes = plt.subplots(4, 3, figsize=(12, 16))
for i in range(4):
    img  = X_val[i]
    true = y_val[i, :, :, 0]
    pred = model3.predict(np.expand_dims(img, 0), verbose=0)[0, :, :, 0]
    axes[i][0].imshow(img);                    axes[i][0].set_title("Input");         axes[i][0].axis('off')
    axes[i][1].imshow(true, cmap='gray');      axes[i][1].set_title("True Mask");     axes[i][1].axis('off')
    axes[i][2].imshow(pred>0.5, cmap='gray');  axes[i][2].set_title("Predicted");     axes[i][2].axis('off')
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/sample_predictions.png')
plt.show()
print("All saved to Drive!")
# Out:
# All saved to Drive!

# %%
import pandas as pd

model_comparison = pd.DataFrame({
    'Model': ['MobileNetV2 U-Net', 'Custom U-Net', 'VGG16 U-Net', 'VGG16 Fine-tuned'],
    'Val Dice':  [0.679, 0.594, 0.672, 0.652],
    'Val IoU':   [0.517, 0.426, 0.466, 0.470],
    'Best Epoch':[6, 90, 10, 7],
    'Stopped At':[16, 100, 25, 17],
    'Augmentation': ['None', 'Basic flip/brightness', 'Albumentations 3x', 'Albumentations 3x'],
    'Encoder Frozen': ['Yes', 'N/A', 'Yes', 'Partial']
})

print("=" * 80)
print("MODEL COMPARISON REPORT")
print("=" * 80)
print(model_comparison.to_string(index=False))

print("\nKEY OBSERVATIONS:")
print("1. Dataset too small (409 images) — train dice hits 0.91 but val dice caps at 0.68")
print("2. MobileNetV2 U-Net performed best (val_dice 0.679) despite no augmentation")
print("3. Augmentation tripled data but didn't significantly improve val_dice")
print("4. All models show overfitting — gap between train/val dice is large")
print("5. Fine-tuning encoder with very low LR (1e-5) did not improve over frozen encoder")
print("6. Inference speed: 237ms single-image (above 100ms target)")
print("   → In batch mode or optimized deployment this would be significantly faster")
# Out:
# ...
# MODEL COMPARISON REPORT
# ...
#             Model  Val Dice  Val IoU  Best Epoch  Stopped At          Augmentation Encoder Frozen
# MobileNetV2 U-Net     0.679    0.517           6          16                  None            Yes
#      Custom U-Net     0.594    0.426          90         100 Basic flip/brightness            N/A
#       VGG16 U-Net     0.672    0.466          10          25     Albumentations 3x            Yes
#  VGG16 Fine-tuned     0.652    0.470           7          17     Albumentations 3x        Partial
#
# KEY OBSERVATIONS:
# 1. Dataset too small (409 images) — train dice hits 0.91 but val dice caps at 0.68
# 2. MobileNetV2 U-Net performed best (val_dice 0.679) despite no augmentation
# 3. Augmentation tripled data but didn't significantly improve val_dice
# 4. All models show overfitting — gap between train/val dice is large
# 5. Fine-tuning encoder with very low LR (1e-5) did not improve over frozen encoder
# ...

# %%
app_code = '''
import streamlit as st
import numpy as np
import cv2
import tensorflow as tf
import tensorflow.keras.backend as K
import time
import pandas as pd
from PIL import Image
import io

# ── Custom functions ─────────────────────────────────────────
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    return dice_loss(y_true, y_pred) + bce

def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# ── Load model ───────────────────────────────────────────────
@st.cache_resource
def load_model():
    return tf.keras.models.load_model(
        "vgg16_unet_best.h5",
        custom_objects={
            "combined_loss": combined_loss,
            "dice_coefficient": dice_coefficient,
            "iou_metric": iou_metric
        }
    )

def preprocess(pil_image):
    img = np.array(pil_image.convert("RGB"))
    img = cv2.resize(img, (256, 256))
    return img / 255.0

def overlay_boxes(original_pil, pred_mask, threshold=0.5):
    img = cv2.resize(np.array(original_pil.convert("RGB")),
                     (pred_mask.shape[1], pred_mask.shape[0]))
    binary = (pred_mask > threshold).astype(np.uint8)
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    result = img.copy()
    face_count = 0
    for cnt in contours:
        if cv2.contourArea(cnt) > 300:
            x, y, w, h = cv2.boundingRect(cnt)
            cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 0), 2)
            cv2.putText(result, f"Face {face_count+1}", (x, y-5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
            face_count += 1
    overlay = result.copy()
    overlay[binary == 1] = [0, 200, 0]
    blended = cv2.addWeighted(result, 0.75, overlay, 0.25, 0)
    return blended, binary, face_count

# ── App Layout ───────────────────────────────────────────────
st.set_page_config(page_title="Scene Cast AI", layout="wide", page_icon="🎬")

st.title("🎬 Scene Cast AI")
st.markdown("### Real-Time Face Segmentation for Movie Cast Identification")
st.markdown("Upload a movie scene image to detect and segment faces instantly.")
st.divider()

model = load_model()

col_upload, col_settings = st.columns([3, 1])
with col_upload:
    uploaded = st.file_uploader("Upload Movie Scene Image", type=["jpg","jpeg","png"])
with col_settings:
    threshold = st.slider("Detection Threshold", 0.1, 0.9, 0.5, 0.05)
    st.caption("Lower = more sensitive, Higher = more precise")

if uploaded:
    pil_image = Image.open(uploaded)

    col1, col2, col3 = st.columns(3)
    col1.subheader("Original")
    col1.image(pil_image, use_column_width=True)

    with st.spinner("Detecting faces..."):
        img_array = preprocess(pil_image)
        img_batch = np.expand_dims(img_array, 0)
        start     = time.time()
        pred_mask = model.predict(img_batch, verbose=0)[0, :, :, 0]
        infer_ms  = (time.time() - start) * 1000

    result_img, binary_mask, face_count = overlay_boxes(pil_image, pred_mask, threshold)
    face_coverage = binary_mask.sum() / binary_mask.size * 100

    col2.subheader("Predicted Mask")
    col2.image((pred_mask * 255).astype(np.uint8), use_column_width=True, clamp=True)

    col3.subheader("Detected Faces")
    col3.image(result_img, use_column_width=True)

    st.divider()
    st.subheader("📊 Performance Dashboard")

    m1, m2, m3, m4 = st.columns(4)
    m1.metric("Faces Detected", face_count)
    m2.metric("Inference Speed", f"{infer_ms:.1f} ms")
    m3.metric("Face Coverage", f"{face_coverage:.1f}%")
    m4.metric("Threshold", threshold)

    st.divider()
    dl1, dl2 = st.columns(2)

    # Download log
    log_df = pd.DataFrame({
        "Metric": ["Faces Detected","Inference Time (ms)","Face Coverage (%)","Threshold"],
        "Value":  [face_count, round(infer_ms,2), round(face_coverage,2), threshold]
    })
    csv_buf = io.StringIO()
    log_df.to_csv(csv_buf, index=False)
    dl1.download_button("⬇ Download Detection Log",
                        data=csv_buf.getvalue(),
                        file_name="detection_log.csv",
                        mime="text/csv")

    # Download result image
    result_pil = Image.fromarray(result_img)
    img_buf = io.BytesIO()
    result_pil.save(img_buf, format="PNG")
    dl2.download_button("⬇ Download Result Image",
                        data=img_buf.getvalue(),
                        file_name="detected_faces.png",
                        mime="image/png")

    st.divider()
    st.subheader("📈 Model Performance Summary")
    perf_df = pd.DataFrame({
        "Model":        ["MobileNetV2 U-Net","Custom U-Net","VGG16 U-Net","VGG16 Fine-tuned"],
        "Val Dice":     [0.679, 0.594, 0.672, 0.652],
        "Val IoU":      [0.517, 0.426, 0.466, 0.470],
        "Augmentation": ["None","Basic","Albumentations 3x","Albumentations 3x"]
    })
    st.dataframe(perf_df, use_container_width=True)

st.markdown("---")
st.caption("Built with TensorFlow + Streamlit | GUVI HCL Final Project — Tania Banerjee")
'''

with open('/content/drive/MyDrive/app.py', 'w') as f:
    f.write(app_code)

print("app.py saved to Drive!")
# Out:
# app.py saved to Drive!

# %%
# !pip install pyngrok -q

# %%
import shutil
shutil.copy('/content/drive/MyDrive/vgg16_unet_best.h5', '/content/vgg16_unet_best.h5')
shutil.copy('/content/drive/MyDrive/app.py', '/content/app.py')
print("Files ready!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_644/1176560193.py in <cell line: 0>()
#       1 import shutil
# ----> 2 shutil.copy('/content/drive/MyDrive/vgg16_unet_best.h5', '/content/vgg16_unet_best.h5')
#       3 shutil.copy('/content/drive/MyDrive/app.py', '/content/app.py')
#       4 print("Files ready!")
#
# /usr/lib/python3.12/shutil.py in copy(src, dst, follow_symlinks)
#     433     if os.path.isdir(dst):
#     434         dst = os.path.join(dst, os.path.basename(src))
# --> 435     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436     copymode(src, dst, follow_symlinks=follow_symlinks)
#     437     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     258         os.symlink(os.readlink(src), dst)
#     259     else:
# --> 260         with open(src, 'rb') as fsrc:
#     261             try:
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
files = os.listdir('/content/drive/MyDrive/')
for f in files:
    if 'vgg16' in f or 'app' in f:
        print(f)
# Out:
# vgg16_unet_best.h5
# app.py

# %%
import shutil
shutil.copy('/content/drive/MyDrive/vgg16_unet_best.h5', '/content/vgg16_unet_best.h5')
shutil.copy('/content/drive/MyDrive/app.py', '/content/app.py')
print("Files ready!")
# Out:
# Files ready!

# %%
# !pip install pyngrok -q

# %%
from pyngrok import ngrok
import subprocess, time

ngrok.set_auth_token("cr_3Daj6hMW8E4m1d1Vh3lVpRZ5HbK")

subprocess.Popen(['streamlit', 'run', '/content/app.py', '--server.port', '8501'])
time.sleep(5)
tunnel = ngrok.connect(8501)
print("App running at:", tunnel.public_url)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_644/3485928174.py in <cell line: 0>()
#       4 ngrok.set_auth_token("cr_3Daj6hMW8E4m1d1Vh3lVpRZ5HbK")
#       5
# ----> 6 subprocess.Popen(['streamlit', 'run', '/content/app.py', '--server.port', '8501'])
#       7 time.sleep(5)
#       8 tunnel = ngrok.connect(8501)
#
# /usr/lib/python3.12/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1024                             encoding=encoding, errors=errors)
#    1025
# -> 1026             self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                                 pass_fds, cwd, env,
# ...

# %%
# !pip install streamlit pyngrok -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 75.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 57.4 MB/s eta 0:00:00

# %%
import os
print(os.path.exists('/content/app.py'))
print(os.path.exists('/content/vgg16_unet_best.h5'))
# Out:
# True
# True

# %%
from pyngrok import ngrok
import subprocess, time

ngrok.set_auth_token("cr_3Daj6hMW8E4m1d1Vh3lVpRZ5HbK")

subprocess.Popen(['streamlit', 'run', '/content/app.py', '--server.port', '8501'])
time.sleep(8)
tunnel = ngrok.connect(8501)
print("App running at:", tunnel.public_url)
# Out:
# ERROR:pyngrok.process.ngrok:t=2026-05-11T19:20:19+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: The authtoken you specified does not look like a proper ngrok authtoken.\nYour authtoken: cr_3Daj6hMW8E4m1d1Vh3lVpRZ5HbK\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# /tmp/ipykernel_644/2961617561.py in <cell line: 0>()
#       6 subprocess.Popen(['streamlit', 'run', '/content/app.py', '--server.port', '8501'])
#       7 time.sleep(8)
# ----> 8 tunnel = ngrok.connect(8501)
#       9 print("App running at:", tunnel.public_url)
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/ngrok.py in connect(addr, proto, name, pyngrok_config, **options)
# ...

# %%
from google.colab import files

# Download the notebook
files.download('/content/drive/MyDrive/app.py')
